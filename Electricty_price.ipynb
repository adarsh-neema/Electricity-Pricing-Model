# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-220a1f23-b408-4f33-80d2-15e1f5a014ea" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-220a1f23-b408-4f33-80d2-15e1f5a014ea">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import numpy as np
import pandas as pd

# %%
x_test.head()
# Out:
#      ID  DAY_ID COUNTRY  DE_CONSUMPTION  FR_CONSUMPTION  DE_FR_EXCHANGE  \
# 0  1115     241      FR        0.340083       -0.433604       -0.423521
# 1  1202    1214      FR        0.803209        0.780411        0.601610
# 2  1194    1047      FR        0.795540        0.721954        1.179158
# 3  1084    1139      FR        0.172555       -0.723427       -0.044539
# 4  1135     842      FR        0.949714        0.420236        0.617391
#
#    FR_DE_EXCHANGE  DE_NET_EXPORT  FR_NET_EXPORT  DE_NET_IMPORT  ...  \
# 0        0.423521       0.165333       0.519419      -0.165333  ...
# 1       -0.601610       0.342802       0.555367      -0.342802  ...
# 2       -1.179158       1.620928       0.666901      -1.620928  ...
# 3        0.044539            NaN      -0.205276            NaN  ...
# 4       -0.617391       0.608561      -0.240856      -0.608561  ...
#
#    FR_RESIDUAL_LOAD   DE_RAIN   FR_RAIN   DE_WIND   FR_WIND   DE_TEMP  \
# ...

# %%
x_test = pd.read_csv("X_test_final.csv")
y_train = pd.read_csv("y_train_ZAN5mwg.csv")
x_train = pd.read_csv("X_train_NHkHMNU.csv")

# %%
print("X_test_shape:",x_test.shape)
print("Y_train_shape",y_train.shape)
print("X_train_shape",x_train.shape)
# Out:
# X_test_shape: (654, 35)
# Y_train_shape (1494, 2)
# X_train_shape (1494, 35)

# %%
x_train.head()
# Out:
#      ID  DAY_ID COUNTRY  DE_CONSUMPTION  FR_CONSUMPTION  DE_FR_EXCHANGE  \
# 0  1054     206      FR        0.210099       -0.427458       -0.606523
# 1  2049     501      FR       -0.022399       -1.003452       -0.022063
# 2  1924     687      FR        1.395035        1.978665        1.021305
# 3   297     720      DE       -0.983324       -0.849198       -0.839586
# 4  1101     818      FR        0.143807       -0.617038       -0.924990
#
#    FR_DE_EXCHANGE  DE_NET_EXPORT  FR_NET_EXPORT  DE_NET_IMPORT  ...  \
# 0        0.606523            NaN       0.692860            NaN  ...
# 1        0.022063      -0.573520      -1.130838       0.573520  ...
# 2       -1.021305      -0.622021      -1.682587       0.622021  ...
# 3        0.839586      -0.270870       0.563230       0.270870  ...
# 4        0.924990            NaN       0.990324            NaN  ...
#
#    FR_RESIDUAL_LOAD   DE_RAIN   FR_RAIN   DE_WIND   FR_WIND   DE_TEMP  \
# ...

# %%
new_df = pd.merge(x_train, y_train, on='ID')

# %%
new_df.tail()
# Out:
#         ID  DAY_ID COUNTRY  DE_CONSUMPTION  FR_CONSUMPTION  DE_FR_EXCHANGE  \
# 1489   459     809      DE        1.529204        1.106682       -1.855327
# 1490  1674     887      FR        1.618582        1.752840        0.611392
# 1491   748    1083      DE        0.856399        0.489199       -0.255778
# 1492  1454    1133      FR        0.560689       -0.343777       -0.830239
# 1493   359    1118      DE        0.226730       -0.711005        0.873016
#
#       FR_DE_EXCHANGE  DE_NET_EXPORT  FR_NET_EXPORT  DE_NET_IMPORT  ...  \
# 1489        1.855327      -0.218658       1.450426       0.218658  ...
# 1490       -0.611392       0.449153      -0.152146      -0.449153  ...
# 1491        0.255778      -1.531544      -0.829568       1.531544  ...
# 1492        0.830239      -0.304856       1.210230       0.304856  ...
# 1493       -0.873016       0.296651      -1.547075      -0.296651  ...
#
#        DE_RAIN   FR_RAIN   DE_WIND   FR_WIND   DE_TEMP   FR_TEMP   GAS_RET  \
# ...

# %%
new_df.describe()
# Out:
#                 ID       DAY_ID  DE_CONSUMPTION  FR_CONSUMPTION  \
# count  1494.000000  1494.000000     1494.000000     1494.000000
# mean   1072.759036   591.861446        0.427442       -0.020032
# std     618.013179   345.065043        0.673412        0.918995
# min       0.000000     0.000000       -2.265563       -1.462350
# 25%     540.250000   292.250000       -0.037421       -0.716771
# 50%    1077.500000   591.000000        0.357061       -0.394166
# 75%    1597.500000   885.750000        0.922057        0.650533
# max    2146.000000  1215.000000        2.033851        3.300640
#
#        DE_FR_EXCHANGE  FR_DE_EXCHANGE  DE_NET_EXPORT  FR_NET_EXPORT  \
# count     1469.000000     1469.000000    1370.000000    1424.000000
# mean        -0.145508        0.145508      -0.256332      -0.072643
# std          0.970226        0.970226       0.957443       1.075830
# min         -2.856874       -2.634831      -2.464849      -2.825331
# ...

# %%
new_df.isnull().sum()
# Out:
# ID                    0
# DAY_ID                0
# COUNTRY               0
# DE_CONSUMPTION        0
# FR_CONSUMPTION        0
# DE_FR_EXCHANGE       25
# FR_DE_EXCHANGE       25
# DE_NET_EXPORT       124
# FR_NET_EXPORT        70
# DE_NET_IMPORT       124
# FR_NET_IMPORT        70
# DE_GAS                0
# FR_GAS                0
# DE_COAL               0
# FR_COAL               0
# DE_HYDRO              0
# FR_HYDRO              0
# DE_NUCLEAR            0
# FR_NUCLEAR            0
# DE_SOLAR              0
# FR_SOLAR              0
# DE_WINDPOW            0
# FR_WINDPOW            0
# DE_LIGNITE            0
# DE_RESIDUAL_LOAD      0
# FR_RESIDUAL_LOAD      0
# DE_RAIN              94
# FR_RAIN              94
# DE_WIND              94
# FR_WIND              94
# DE_TEMP              94
# FR_TEMP              94
# GAS_RET               0
# COAL_RET              0
# CARBON_RET            0
# TARGET                0
# dtype: int64

# %%
new_df[new_df['DE_FR_EXCHANGE'].isnull()]
# Out:
#        ID  DAY_ID COUNTRY  DE_CONSUMPTION  FR_CONSUMPTION  DE_FR_EXCHANGE  \
# 19    964     804      FR        1.585749        2.632105             NaN
# 39    935      52      FR        1.231695        1.269656             NaN
# 61    936      28      FR        1.408520        1.391108             NaN
# 64    955    1069      FR        1.196808        2.342962             NaN
# 152   959     744      FR        1.099693        1.570898             NaN
# 299   958     126      FR        1.203701        1.399900             NaN
# 337   934     740      FR        0.683673        0.813651             NaN
# 401   938     874      FR        1.130684        1.382883             NaN
# 459   953     186      FR        1.418318        2.410895             NaN
# 468   951      58      FR        1.472340        2.439284             NaN
# 754   946     308      FR        1.542430        1.293023             NaN
# 864   945     927      FR        1.322486        1.171245             NaN
# ...

# %%
new_df['COUNTRY'].value_counts()
# Out:
# FR    851
# DE    643
# Name: COUNTRY, dtype: int64

# %%
new_df['DE_FR_EXCHANGE']
# Out:
# 0      -0.606523
# 1      -0.022063
# 2       1.021305
# 3      -0.839586
# 4      -0.924990
#           ...
# 1489   -1.855327
# 1490    0.611392
# 1491   -0.255778
# 1492   -0.830239
# 1493    0.873016
# Name: DE_FR_EXCHANGE, Length: 1494, dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
columns_to_plot = [
    "DE_FR_EXCHANGE", "FR_DE_EXCHANGE", "DE_RAIN", "FR_RAIN",
    "DE_WIND", "FR_WIND", "DE_TEMP", "FR_TEMP",
    "DE_NET_EXPORT", "FR_NET_EXPORT", "DE_NET_IMPORT", "FR_NET_IMPORT"
]

# Create a boxplot for each column
plt.figure(figsize=(15, 8))
sns.boxplot(data=new_df[columns_to_plot])
plt.title('Boxplots of Selected Columns')
plt.xlabel('Columns')
plt.ylabel('Values')

# Rotate x-axis labels for better readability
plt.xticks(rotation=45, ha='right')

# Display the plot
plt.show()

# %%
mean = new_df["DE_FR_EXCHANGE"].mean()
new_df["DE_FR_EXCHANGE"].fillna(mean, inplace=True)

mean = new_df["DE_FR_EXCHANGE"].mean()
new_df["DE_FR_EXCHANGE"].fillna(mean, inplace=True)

mean = new_df["DE_TEMP"].mean()
new_df["DE_TEMP"].fillna(mean, inplace=True)

mean = new_df["FR_TEMP"].mean()
new_df["FR_TEMP"].fillna(mean, inplace=True)

mean = new_df["DE_NET_EXPORT"].mean()
new_df["DE_NET_EXPORT"].fillna(mean, inplace=True)

mean = new_df["FR_NET_EXPORT"].mean()
new_df["FR_NET_EXPORT"].fillna(mean, inplace=True)

mean = new_df["DE_NET_IMPORT"].mean()
new_df["DE_NET_IMPORT"].fillna(mean, inplace=True)

mean = new_df["FR_NET_IMPORT"].mean()
new_df["FR_NET_IMPORT"].fillna(mean, inplace=True)

mean = new_df["FR_DE_EXCHANGE"].mean()
new_df["FR_DE_EXCHANGE"].fillna(mean, inplace=True)


mean = new_df["DE_RAIN"].mean()
new_df["DE_RAIN"].fillna(mean, inplace=True)

mean = new_df["FR_RAIN"].mean()
new_df["FR_RAIN"].fillna(mean, inplace=True)

mean = new_df["DE_WIND"].mean()
new_df["DE_WIND"].fillna(mean, inplace=True)

mean = new_df["FR_WIND"].mean()
new_df["FR_WIND"].fillna(mean, inplace=True)

# %%
new_df.isnull().sum()
# Out:
# ID                  0
# DAY_ID              0
# COUNTRY             0
# DE_CONSUMPTION      0
# FR_CONSUMPTION      0
# DE_FR_EXCHANGE      0
# FR_DE_EXCHANGE      0
# DE_NET_EXPORT       0
# FR_NET_EXPORT       0
# DE_NET_IMPORT       0
# FR_NET_IMPORT       0
# DE_GAS              0
# FR_GAS              0
# DE_COAL             0
# FR_COAL             0
# DE_HYDRO            0
# FR_HYDRO            0
# DE_NUCLEAR          0
# FR_NUCLEAR          0
# DE_SOLAR            0
# FR_SOLAR            0
# DE_WINDPOW          0
# FR_WINDPOW          0
# DE_LIGNITE          0
# DE_RESIDUAL_LOAD    0
# FR_RESIDUAL_LOAD    0
# DE_RAIN             0
# FR_RAIN             0
# DE_WIND             0
# FR_WIND             0
# DE_TEMP             0
# FR_TEMP             0
# GAS_RET             0
# COAL_RET            0
# CARBON_RET          0
# TARGET              0
# dtype: int64

# %%
new_df.head()
# Out:
#      ID  DAY_ID COUNTRY  DE_CONSUMPTION  FR_CONSUMPTION  DE_FR_EXCHANGE  \
# 0  1054     206      FR        0.210099       -0.427458       -0.606523
# 1  2049     501      FR       -0.022399       -1.003452       -0.022063
# 2  1924     687      FR        1.395035        1.978665        1.021305
# 3   297     720      DE       -0.983324       -0.849198       -0.839586
# 4  1101     818      FR        0.143807       -0.617038       -0.924990
#
#    FR_DE_EXCHANGE  DE_NET_EXPORT  FR_NET_EXPORT  DE_NET_IMPORT  ...   DE_RAIN  \
# 0        0.606523      -0.256332       0.692860       0.256332  ... -0.172680
# 1        0.022063      -0.573520      -1.130838       0.573520  ... -1.240300
# 2       -1.021305      -0.622021      -1.682587       0.622021  ... -0.480700
# 3        0.839586      -0.270870       0.563230       0.270870  ... -1.114838
# 4        0.924990      -0.256332       0.990324       0.256332  ... -0.541465
#
# ...

# %%
new_df.head()
# Out:
#      ID  DAY_ID COUNTRY  DE_CONSUMPTION  FR_CONSUMPTION  DE_FR_EXCHANGE  \
# 0  1054     206      FR        0.210099       -0.427458       -0.606523
# 1  2049     501      FR       -0.022399       -1.003452       -0.022063
# 2  1924     687      FR        1.395035        1.978665        1.021305
# 3   297     720      DE       -0.983324       -0.849198       -0.839586
# 4  1101     818      FR        0.143807       -0.617038       -0.924990
#
#    FR_DE_EXCHANGE  DE_NET_EXPORT  FR_NET_EXPORT  DE_NET_IMPORT  ...  \
# 0        0.606523      -0.256332       0.692860       0.256332  ...
# 1        0.022063      -0.573520      -1.130838       0.573520  ...
# 2       -1.021305      -0.622021      -1.682587       0.622021  ...
# 3        0.839586      -0.270870       0.563230       0.270870  ...
# 4        0.924990      -0.256332       0.990324       0.256332  ...
#
#    FR_RESIDUAL_LOAD   DE_RAIN   FR_RAIN   DE_WIND   FR_WIND   DE_TEMP  \
# ...

# %%
new_df.drop("ID",axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-76-9b404f6c6098> in <cell line: 1>()
# ----> 1 new_df.drop("ID",axis=1,inplace=True)
#       2 new_df.drop("DAY_ID",axis=1,inplace=True)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5397                 weight  1.0     0.8
#    5398         """
# -> 5399         return super().drop(
#    5400             labels=labels,
#    5401             axis=axis,
#
# ...

# %%
new_df.drop("DAY_ID",axis=1,inplace=True)

# %%
new_df['COUNTRY'].replace({'FR': 0, 'DE': 1}, inplace=True)

# %%
# prompt: copy the TARGET column in new column and drop it from the orignal column
y_train.head()
# Out:
#      TARGET
# 0  0.028313
# 1 -0.112516
# 2 -0.180840
# 3 -0.260356
# 4 -0.071733

# %%
y_train.tail()
# Out:
#         TARGET
# 1489 -0.172597
# 1490 -0.063546
# 1491  0.151797
# 1492 -0.640917
# 1493 -0.252764

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(new_df, y_train, test_size=0.2, random_state = 42)

# %%
from sklearn.linear_model import LinearRegression
reg = LinearRegression()
reg.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
y_pred = reg.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error, r2_score
mse = mean_squared_error(Y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(Y_test, y_pred)

print("RMSE:", rmse)
print("MSE", mse)
print("R2", r2)
# Out:
# RMSE: 1.0916970411942881
# MSE 1.191802429752363
# R2 0.00215185883995761

# %%
x_test.isnull().sum()
# Out:
# ID                   0
# DAY_ID               0
# COUNTRY              0
# DE_CONSUMPTION       0
# FR_CONSUMPTION       0
# DE_FR_EXCHANGE       9
# FR_DE_EXCHANGE       9
# DE_NET_EXPORT       47
# FR_NET_EXPORT       24
# DE_NET_IMPORT       47
# FR_NET_IMPORT       24
# DE_GAS               0
# FR_GAS               0
# DE_COAL              0
# FR_COAL              0
# DE_HYDRO             0
# FR_HYDRO             0
# DE_NUCLEAR           0
# FR_NUCLEAR           0
# DE_SOLAR             0
# FR_SOLAR             0
# DE_WINDPOW           0
# FR_WINDPOW           0
# DE_LIGNITE           0
# DE_RESIDUAL_LOAD     0
# FR_RESIDUAL_LOAD     0
# DE_RAIN             40
# FR_RAIN             40
# DE_WIND             40
# FR_WIND             40
# DE_TEMP             40
# FR_TEMP             40
# GAS_RET              0
# COAL_RET             0
# CARBON_RET           0
# dtype: int64

# %%
mean = x_test["DE_FR_EXCHANGE"].mean()
x_test["DE_FR_EXCHANGE"].fillna(mean, inplace=True)

mean = x_test["DE_FR_EXCHANGE"].mean()
x_test["DE_FR_EXCHANGE"].fillna(mean, inplace=True)

mean = x_test["DE_TEMP"].mean()
x_test["DE_TEMP"].fillna(mean, inplace=True)

mean = x_test["FR_TEMP"].mean()
x_test["FR_TEMP"].fillna(mean, inplace=True)

mean = x_test["DE_NET_EXPORT"].mean()
x_test["DE_NET_EXPORT"].fillna(mean, inplace=True)

mean = x_test["FR_NET_EXPORT"].mean()
x_test["FR_NET_EXPORT"].fillna(mean, inplace=True)

mean = x_test["DE_NET_IMPORT"].mean()
x_test["DE_NET_IMPORT"].fillna(mean, inplace=True)

mean = x_test["FR_NET_IMPORT"].mean()
x_test["FR_NET_IMPORT"].fillna(mean, inplace=True)

mean = x_test["FR_DE_EXCHANGE"].mean()
x_test["FR_DE_EXCHANGE"].fillna(mean, inplace=True)


mean = x_test["DE_RAIN"].mean()
x_test["DE_RAIN"].fillna(mean, inplace=True)

mean = x_test["FR_RAIN"].mean()
x_test["FR_RAIN"].fillna(mean, inplace=True)

mean = x_test["DE_WIND"].mean()
x_test["DE_WIND"].fillna(mean, inplace=True)

mean = x_test["FR_WIND"].mean()
x_test["FR_WIND"].fillna(mean, inplace=True)

# %%
x_test.drop("ID",axis=1,inplace=True)

# %%
x_test.drop("DAY_ID",axis=1,inplace=True)

# %%
x_test['COUNTRY'].replace({'FR': 0, 'DE': 1}, inplace=True)

# %%
#Tesing on the testing set.
y_pred_new = reg.predict(X_test)
y_pred_new
# Out:
# array([[ 5.69879581e-02],
#        [-9.37749158e-02],
#        [-2.69273149e-01],
#        [ 1.83892142e-01],
#        [ 3.90881890e-01],
#        [ 9.28251917e-02],
#        [-2.59406066e-01],
#        [-4.20648282e-01],
#        [ 6.14383809e-02],
#        [-1.87233589e-01],
#        [ 1.33193115e-01],
#        [-4.22406632e-01],
#        [ 1.26191980e-01],
#        [-1.53306671e-02],
#        [ 5.07462609e-01],
#        [ 2.17912401e-01],
#        [ 9.20747519e-03],
#        [ 1.46393909e-01],
#        [-4.61212907e-01],
#        [-4.33891323e-01],
#        [ 1.26140548e-01],
#        [ 9.63816482e-02],
#        [ 1.30824428e-01],
#        [ 3.91158993e-01],
#        [-8.80536318e-02],
#        [ 3.23734865e-03],
#        [-1.08756332e-01],
#        [-8.23561798e-02],
#        [ 2.42538250e-01],
#        [ 1.59881262e-01],
#        [ 3.24056267e-02],
#        [ 1.44270592e-01],
#        [ 3.25164673e-01],
#        [ 4.49309344e-01],
#        [-3.83507062e-02],
# ...
